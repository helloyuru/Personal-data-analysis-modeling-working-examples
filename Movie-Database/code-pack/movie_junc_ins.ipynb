# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import seaborn as sb

# %%
df1= pd.read_csv('temp_3.csv')

# %%
df1.head(5)
# Out:
#    post_id                                            context  like_count  \
# 0        1  Seeing DisneyNature's Penguins in IMAX! Always...          10
# 1       44  Where’s your #tropical #oasis ?? #comment #tro...          30
# 2       57  RIP Tampa and Pittsburgh.\n.\n.\n.\nLots of ta...           5
# 3       70  Catch you on the flip side! Follow Steve as he...          11
# 4       93  #penguin #penguins #penguinsofantarctica #peng...           7
#
#    comments_count  hashtags    ins_date  ins_time      temp1     temp2  \
# 0               0  penguins  2019-04-17  23:10:46  Penguins   Penguins
# 1               0  penguins  2019-05-30  23:10:46  Penguins   Penguins
# 2               0  penguins  2019-06-12  23:10:46  Penguins   Penguins
# 3               0  penguins  2019-06-25  23:10:46  Penguins   Penguins
# 4               0  penguins  2019-07-18  23:10:46  Penguins   Penguins
#
#    new_movie_id      title runtime        genre  \
# ...

# %%
df2=df1.drop(['context', 'like_count', 'comments_count','hashtags','ins_date','ins_time','temp1','temp2','title','runtime','genre','director','stars','outline'], axis=1)

# %%
df3=df2[['new_movie_id','post_id']]

# %%
df3
# Out:
#     new_movie_id  post_id
# 0              0        1
# 1              0       44
# 2              0       57
# 3              0       70
# 4              0       93
# 5              1      117
# 6              1      125
# 7              1      153
# 8              1      172
# 9              1      186
# 10             2      190
# 11             2      208
# 12             2      240
# 13             2      254
# 14             2      260
# 15             3      286
# 16             3      299
# 17             3      310
# 18             3      341
# 19             4      352
# 20             4      355
# 21             4      358
# 22             4      373
# 23             5      376
# 24             5      386
# 25             5      387
# 26             5      391
# 27             5      410
# 28             6      438
# 29             6      447
# ..           ...      ...
# 65            15      991
# 66            15     1022
# 67            16     1033
# ...

# %%
df3.to_csv('movie_junc_ins.csv', sep=',',index=False)
